# %% [markdown]
# # Recommender System Challenge

# %%
#Importing libraries
import pandas as pd
import scipy.sparse as sparse
import implicit
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
#Loading all the csv files
flickr_links = pd.read_csv("res2021/flickr_links.csv")
flickr_item_features = pd.read_csv("res2021/flickr_item_fea.csv")
flickr_train_data = pd.read_csv("res2021/flickr_train_data.csv")
flickr_test_data = pd.read_csv("res2021/flickr_test_data.csv")
flickr_user_features = pd.read_csv("res2021/flickr_user_fea.csv")
flickr_validation_data = pd.read_csv("res2021/flickr_validation_data.csv")
flickr_sample_solution_data = pd.read_csv("res2021/sample_solution_data.csv")

# %%
flickr_train_data.head()
# Out:
#    user_id  item_id  rating
# 0        0        0       1
# 1        0        1       1
# 2        0        2       1
# 3        0        3       1
# 4        0        4       1

# %%
#unique user id's in the train data
flickr_train_data['user_id'].nunique()
# Out:
# 3466

# %%
#unique item id's in the train data
flickr_train_data['item_id'].nunique()
# Out:
# 9004

# %%
#maximum number in the user id's
max(flickr_train_data['user_id'])
# Out:
# 3465

# %%
#minimum number in the user id's
min(flickr_train_data['user_id'])
# Out:
# 0

# %%
# max and min item id value
max(flickr_train_data['item_id']),min(flickr_train_data['item_id'])
# Out:
# (9003, 0)

# %%
# finding the unique values for the rating
flickr_train_data['rating'].nunique()
# Out:
# 1

# %%
# finding value counts for the ratings in train data
flickr_train_data['rating'].value_counts()
# Out:
# 1    110129
# Name: rating, dtype: int64

# %%
# creating sparse matrix
sparse_item_user = sparse.csr_matrix((flickr_train_data['rating'].astype(float), (flickr_train_data['item_id'], flickr_train_data['user_id'])))
sparse_user_item = sparse.csr_matrix((flickr_train_data['rating'].astype(float), (flickr_train_data['user_id'], flickr_train_data['item_id'])))

# %%
sparse_item_user
# Out:
# <9004x3466 sparse matrix of type '<class 'numpy.float64'>'
# 	with 110129 stored elements in Compressed Sparse Row format>

# %%
sparse_user_item
# Out:
# <3466x9004 sparse matrix of type '<class 'numpy.float64'>'
# 	with 110129 stored elements in Compressed Sparse Row format>

# %%
alpha = 30 #increasing the confidence in a preference with more interactions
data = (sparse_item_user * alpha).astype('double')

# %%
# Checking the datatype of data variable
type(data)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
data[1,:].todense()
# Out:
# matrix([[30.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
user_items = sparse_item_user.T.tocsr() #taking the transpose of sparse item user sparse matrix and turning into gensim document format.

# %%
# Intersection function
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return list(lst3)

# %% [markdown]
# # Collaborative Filtering for Implicit Feedback Datasets

# %% [markdown]
# ## AlternatingLeastSquares

# %%
#fitting the data using ALS in Implicit package
model = implicit.als.AlternatingLeastSquares(factors=8, regularization=0.3, iterations=100)
model.fit(data)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#unique user id's in the train data
flickr_train_data['user_id'].nunique()
# Out:
# 3466

# %%
#unique item id's in the train data
flickr_train_data['item_id'].nunique()
# Out:
# 9004

# %%
# Considering all the item recommendations for each user and finding the first top 15 recommended items 
# based on the item list in the test set for each user.
items = []
users = []
for i in range(3466):
    recommendations = model.recommend(i, user_items, N=9004)
    reco = []
    for recommendation in recommendations:
        reco.append(recommendation[0])
    score_list = intersection(reco,list(flickr_test_data[flickr_test_data['user_id']==i]['item_id']))
    items.append(score_list[:15])
    users.append([i,i,i,i,i,i,i,i,i,i,i,i,i,i,i])

# %%
# length of the items and users
len(items),len(users) #total 3466 lists in both users and items list
# Out:
# (3466, 3466)

# %%
# Flattening both the lists
flat_users = [item for sublist in users for item in sublist]
flat_items = [item for sublist in items for item in sublist]

# %%
#Zipping both the flattened lists
zipped_list = list(zip(flat_users,flat_items))

# %%
# Converting into csv file with the required format
final = pd.DataFrame(zipped_list, columns=['user_id','item_id'])
final.to_csv("final2.csv",index=False)

# %%
# 15 recommended items for the user '0'
model.recommend(0,user_items, N = 15)
# Out:
# [(4745, 0.32525814),
#  (379, 0.31874484),
#  (30, 0.31701577),
#  (42, 0.30983996),
#  (3610, 0.30440012),
#  (3588, 0.30005553),
#  (73, 0.29754508),
#  (8416, 0.294688),
#  (284, 0.28752795),
#  (335, 0.28620598),
#  (3612, 0.2860352),
#  (56, 0.28253418),
#  (3083, 0.282198),
#  (4833, 0.28189278),
#  (26, 0.28020525)]

# %%
# 15 recommended items after considering the test set items for user '0'
final[final['user_id']==0]
# Out:
#     user_id  item_id
# 0         0     7128
# 1         0     6343
# 2         0     1267
# 3         0     7091
# 4         0     3450
# 5         0     8275
# 6         0      838
# 7         0     3598
# 8         0     2607
# 9         0     1068
# 10        0     8906
# 11        0     3448
# 12        0      885
# 13        0     1365
# 14        0     7036

# %% [markdown]
# ## LogisticMatrixFactorization

# %%
# fitting the data using LogisticMatrixFactorization in Implicit package
model1 = implicit.lmf.LogisticMatrixFactorization(factors = 5, regularization = 0.2, iterations = 50)
model1.fit(data)
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 61.33it/s]

# %%
#unique user id's in the train data
flickr_train_data['user_id'].nunique()
# Out:
# 3466

# %%
#unique item id's in the train data
flickr_train_data['item_id'].nunique()
# Out:
# 9004

# %%
# Considering all the item recommendations for each user and finding the first top 15 recommended items 
# based on the item list in the test set for each user.
items = []
users = []
for i in range(3466):
    recommendations = model1.recommend(i, user_items, N=9004)
    reco = []
    for recommendation in recommendations:
        reco.append(recommendation[0])
    score_list = intersection(reco,list(flickr_test_data[flickr_test_data['user_id']==i]['item_id']))
    items.append(score_list[:15])
    users.append([i,i,i,i,i,i,i,i,i,i,i,i,i,i,i])

# %%
len(items),len(users) #3466 lists in the items and users lists.
# Out:
# (3466, 3466)

# %%
# Flattening both the lists
flat_users = [item for sublist in users for item in sublist]
flat_items = [item for sublist in items for item in sublist]

# %%
#Zipping the flattened lists
zipped_list = list(zip(flat_users,flat_items))

# %%
# Converting into csv file with the required format
final = pd.DataFrame(zipped_list, columns=['user_id','item_id'])
final.to_csv("final1.csv",index=False)

# %%
# 15 recommended items for the user '0' based on LogisticMatrixFactorization
model1.recommend(0,user_items, N = 15)
# Out:
# [(1926, 11.578138),
#  (237, 10.826538),
#  (7611, 10.698066),
#  (6219, 10.580546),
#  (1502, 10.454693),
#  (5292, 9.606646),
#  (1082, 9.508778),
#  (1100, 9.396305),
#  (941, 9.358452),
#  (5018, 9.245006),
#  (2931, 9.237265),
#  (4812, 9.231532),
#  (5771, 9.215851),
#  (2182, 9.142419),
#  (777, 9.066832)]

# %%
# 15 recommended items after considering the test set items for user '0' using LogisticMatrixFactorization in implicit package
final[final['user_id']==0]
# Out:
#     user_id  item_id
# 0         0     7524
# 1         0     5029
# 2         0      691
# 3         0     3103
# 4         0     8552
# 5         0      838
# 6         0     8544
# 7         0     4713
# 8         0     1214
# 9         0       48
# 10        0     1447
# 11        0     1859
# 12        0      740
# 13        0      370
# 14        0     6343

# %% [markdown]
# # Node Clustering in Graphs

# %%
#Importing libraries
import networkx as nx
import scipy as sp
import numpy as np
import torch

# %%
#Setting seed
torch.manual_seed(4179)

# %%
# Finding the nuumber of lines in the adjedges.txt file
number_of_lines = len(open('adjedges.txt').readlines())
print(number_of_lines)
# Out:
# 18720

# %%
# Dictionary to store to nodes and their edges with other nodes
edges_dict = {}
with open('adjedges.txt', 'r') as adjedges:
    adjedges = [adjedges.readline().strip() for i in range(0,number_of_lines)]
    for each_link in adjedges:
        nodes = each_link.split(' ')[0]
        edges = each_link.split(' ')[1:]
        edges_dict[nodes] = edges

# %%
edges_dict
# Out:
# {'12828558': [],
#  '66779408': [],
#  '38902949': ['38998399'],
#  '33450563': ['26547200'],
#  '57470294': ['20968604'],
#  '12016981': [],
#  '59453341': [],
#  '54791317': ['9564967', '14589786'],
#  '38124547': [],
#  '44569330': [],
#  '4289706': ['48119811'],
#  '34733903': [],
#  '67315895': ['47074959',
#   '36354718',
#   '38323242',
#   '40935482',
#   '77107975',
#   '38994139',
#   '48871207',
#   '75049959',
#   '68339148',
#   '62098573',
#   '66337421',
#   '78106693'],
#  '47899676': [],
#  '58164272': [],
#  '76914035': [],
#  '71555172': [],
#  '6909690': ['56473434'],
#  '47982561': ['26890304', '64372150'],
#  '16864792': ['9684893', '47949816', '47887794'],
#  '34534740': ['48119811', '16482894'],
#  '27917678': ['44783549', '24245729', '33207680', '66903997'],
#  '42441879': [],
#  '20060161': [],
#  '54709047': ['9633322', '32043684', '45159388', '54592233'],
#  '17112646': ['17381885', '33338932'],
#  '41499729': [],
#  '39772251': [],
#  '71431551': [],
#  '34646799': [],
#  '72286508': ['39750483'],
#  '30054787': ['63059055',
#   '62862974',
#   '73820982',
#   '73329207',
#   '3895304',
#   '62788245',
#   '52334001',
#   '33043298',
#   '28330077',
#   '63065670',
#   '19535575',
#   '76772526',
#   '41924527',
#   '27845256'],
#  '14960319': [],
#  '20894906': [],
#  '43560951': ['54197146'],
#  '12233872': [],
#  '58790184': ['70057386'],
#  '41345168': ['38966407'],
#  '53029990': [],
#  '17009966': ['23931260'],
#  '23095245': [],
#  '39006078': [],
#  '22637451': [],
#  '1418126': ['1329161', '45438437'],
#  '61597421': [],
#  '62350848': [],
#  '38208385': [],
#  '54562160': [],
#  '47946998': [],
#  '71174685': [],
#  '40035502': [],
#  '14982527': [],
#  '18559780': ['18459291', '18564228'],
#  '72501271': ['19382220'],
#  '10048225': ['59434204'],
#  '40080547': [],
#  '44483771': ['71432789'],
#  '6209405': [],
#  '32265946': [],
#  '6636178': ['38388952'],
#  '38419714': ['75596722', '57414839', '23935236', '17388721', '58195006'],
#  '39765555': [],
#  '47903875': ['67987969'],
#  '38908219': [],
#  '17144632': [],
#  '32405512': ['5244580'],
#  '58264095': ['73887338'],
#  '10592146': ['48130019'],
#  '27757876': [],
#  '12204756': [],
#  '71425739': [],
#  '10706160': [],
#  '47972984': [],
#  '22492574': [],
#  '35921598': [],
#  '52837837': ['65965087'],
#  '60341713': ['60046126', '21477869', '38913188', '24427908'],
#  '55648908': ['39047603',
#   '23966739',
#   '42462247',
#   '24279253',
#   '26547200',
#   '33404747',
#   '24388931',
#   '17003474'],
#  '14875594': [],
#  '14875759': [],
#  '48678541': ['48480134'],
#  '6479945': [],
#  '11546941': ['13343751'],
#  '34805002': [],
#  '21894266': [],
#  '40202931': [],
#  '41120230': [],
#  '61653787': [],
#  '30370202': [],
#  '41315669': [],
#  '76250257': [],
#  '4122517': [],
#  '71522410': [],
#  '46924819': ['75751275', '47056311', '33903836'],
#  '4925897': [],
#  '9653400': [],
#  '47608867': [],
#  '21909791': [],
#  '2910962': [],
#  '47689611': [],
#  '41333868': [],
#  '12851109': [],
#  '48010264': [],
#  '55708499': [],
#  '24354444': [],
#  '2558656': [],
#  '21092817': [],
#  '61641625': [],
#  '24294943': [],
#  '5665481': ['50096270', '5820242', '50165841', '50144491'],
#  '17664420': [],
#  '9513316': ['37924409'],
#  '30173134': [],
#  '48513318': [],
#  '49244403': [],
#  '39795788': [],
#  '34757287': [],
#  '27583382': [],
#  '20157519': [],
#  '28456696': ['13979317', '28495772'],
#  '20376508': [],
#  '11695845': [],
#  '44299936': [],
#  '14882075': ['12933854'],
#  '14788728': ['58273579'],
#  '41209535': [],
#  '41151647': [],
#  '18445831': [],
#  '41343198': [],
#  '28577858': [],
#  '38798521': [],
#  '62371398': ['17381885', '10706382'],
#  '75995928': ['45054432'],
#  '68358553': [],
#  '23722119': [],
#  '37857050': [],
#  '22529282': [],
#  '78122623': [],
#  '10466497': [],
#  '41164006': [],
#  '26454883': [],
#  '4970781': [],
#  '10390994': [],
#  '39879054': ['48114713', '75251938'],
#  '12627824': [],
#  '43166750': [],
#  '1066092': [],
#  '41336770': [],
#  '43039862': [],
#  '38797216': [],
#  '15016187': ['33207680'],
#  '36780153': [],
#  '36643490': [],
#  '28737890': [],
#  '10307904': [],
#  '23868126': [],
#  '39972783': [],
#  '38937933': ['58174272'],
#  '41496134': [],
#  '38827890': [],
#  '15247739': [],
#  '20899547': ['17381885', '54195161'],
#  '53023736': [],
#  '38764349': [],
#  '71415626': [],
#  '54917546': [],
#  '71439214': [],
#  '49436076': [],
#  '54992365': [],
#  '41304088': ['41324761'],
#  '24304624': [],
#  '39719760': [],
#  '11415195': [],
#  '31604510': [],
#  '25962005': [],
#  '39777387': ['38913188'],
#  '41291987': [],
#  '48288333': ['65342808', '19030169'],
#  '14772078': [],
#  '62516668': ['38365510', '47846726'],
#  '21941140': [],
#  '24772788': [],
#  '49327894': ['32901249', '28124223', '12484883', '67970819', '68074136'],
#  '23940295': [],
#  '78051252': ['52237589',
#   '20638218',
#   '19404397',
#   '46495393',
#   '75378824',
#   '75316565',
#   '66359362'],
#  '71640753': ['36679873', '48869488'],
#  '12810390': [],
#  '78304440': [],
#  '38454176': ['20166414'],
#  '61149976': [],
#  '14771338': [],
#  '30347996': ['20879532', '64415468', '16413154'],
#  '24063423': [],
#  '4752672': [],
#  '33246577': ['77456662', '24255044'],
#  '41619933': [],
#  '41646861': ['71603297'],
#  '58220404': [],
#  '10101505': [],
#  '21125761': [],
#  '47975082': ['64907113', '67964144'],
#  '41134045': [],
#  '33217458': [],
#  '14891394': [],
#  '14729714': [],
#  '58295469': [],
#  '39982987': [],
#  '16889612': [],
#  '58388309': ['41395142', '26547200', '71375217', '77644666', '24279253'],
#  '71378273': [],
#  '27746891': [],
#  '31534190': ['66536758'],
#  '69118961': ['57723463'],
#  '68373032': [],
#  '41411255': [],
#  '68225895': [],
#  '20980568': [],
#  '9496751': ['59075664'],
#  '26565898': ['65064479', '27376840', '73444014'],
#  '58557307': ['75084009', '59646986', '1244120', '53089955'],
#  '16864312': [],
#  '6037711': [],
#  '17171119': ['8991519'],
#  '173889': [],
#  '10439370': ['46108864'],
#  '5617161': [],
#  '29148119': ['17381885'],
#  '58294066': ['14974314', '71510534', '38660355'],
#  '46057239': [],
#  '24069155': [],
#  '61572401': [],
#  '56071758': [],
#  '12578252': [],
#  '12165989': [],
#  '68299079': [],
#  '66140144': [],
#  '28893614': [],
#  '34635686': [],
#  '71251765': [],
#  '50752517': [],
#  '21972954': [],
#  '1672961': ['75546580'],
#  '59059111': [],
#  '38924375': ['47978889'],
#  '49317707': [],
#  '71137680': [],
#  '16108347': [],
#  '28616654': [],
#  '24430361': [],
#  '69353883': [],
#  '39048535': [],
#  '39003766': ['68175070'],
#  '61537477': [],
#  '77120777': [],
#  '24390096': ['16921144'],
#  '30113491': [],
#  '59483832': [],
#  '72019098': ['49392138'],
#  '68042128': [],
#  '68901967': ['41299827', '56907856'],
#  '58392932': [],
#  '18755216': [],
#  '52940064': [],
#  '27382572': ['20366981', '24384952'],
#  '66393674': [],
#  '34485235': [],
#  '15014594': ['9956960'],
#  '4929958': ['33481774', '38835874'],
#  '47958938': [],
#  '71282186': [],
#  '23979720': [],
#  '40166660': [],
#  '47073715': ['41245535'],
#  '1759342': ['55585685', '43412629', '59764119'],
#  '61739905': [],
#  '62552337': [],
#  '39988416': [],
#  '41155604': ['58317297', '37010405'],
#  '31161813': ['44391295',
#   '63225143',
#   '77528604',
#   '48422067',
#   '77131749',
#   '4006956',
#   '35823628',
#   '52818692',
#   '50977401'],
#  '38856210': [],
#  '11718927': [],
#  '18538685': [],
#  '33650615': [],
#  '24305544': [],
#  '66104530': [],
#  '77143630': [],
#  '7755678': ['26278432'],
#  '23431945': ['8431826', '43499797'],
#  '48084177': [],
#  '68172232': [],
#  '24929027': ['37404058'],
#  '47973358': [],
#  '68157888': ['37040165'],
#  '32043684': ['14974314', '23718325', '28586168', '33404747'],
#  '38950127': [],
#  '21696827': [],
#  '67857807': [],
#  '21120101': [],
#  '6628255': [],
#  '38545472': [],
#  '7607033': [],
#  '34538987': [],
#  '69237364': [],
#  '16846973': [],
#  '58265390': [],
#  '43211472': [],
#  '67416370': [],
#  '41523113': [],
#  '10715981': [],
#  '6692256': [],
#  '41628667': ['71324843'],
#  '69506486': [],
#  '68437247': ['31252704', '24244750'],
#  '62444762': [],
#  '41261282': [],
#  '11783496': [],
#  '24381181': [],
#  '9835099': [],
#  '12808129': [],
#  '31956150': [],
#  '11686379': ['2998155'],
#  '8163785': ['41940338', '8277831'],
#  '47882750': ['71526972',
#   '28315643',
#   '71490262',
#   '48055965',
#   '33207680',
#   '66768360',
#   '58362423',
#   '14781818'],
#  '23956993': [],
#  '38496230': [],
#  '38832438': [],
#  '76569872': [],
#  '43193462': [],
#  '41273776': [],
#  '40578486': [],
#  '48023609': [],
#  '66163292': ['43422690'],
#  '46973934': ['43125900', '34322828', '16413154'],
#  '1927922': [],
#  '31142879': ['42786582'],
#  '37833861': [],
#  '20931265': [],
#  '41535039': [],
#  '10648670': [],
#  '39957493': [],
#  '14999062': [],
#  '35926213': [],
#  '48021246': [],
#  '24420113': [],
#  '10455461': [],
#  '24066961': [],
#  '41088230': [],
#  '71997781': [],
#  '74134188': [],
#  '24337290': [],
#  '33835248': [],
#  '14965504': [],
#  '14402931': [],
#  '41490200': ['31177933'],
#  '6207388': ['48721632', '41187392', '41028054', '61517536'],
#  '10633811': [],
#  '14783772': [],
#  '39985569': [],
#  '41725313': [],
#  '24196018': [],
#  '14762137': ['33330788'],
#  '34732837': [],
#  '2674219': [],
#  '15008773': [],
#  '69456069': [],
#  '44326112': [],
#  '33883329': [],
#  '6464062': [],
#  '77028800': [],
#  '64032454': ['77252024',
#   '75751275',
#   '72594068',
#   '33903836',
#   '60284597',
#   '45861848',
#   '60148955'],
#  '40337167': [],
#  '29615978': [],
#  '33071446': ['32901249', '33422831'],
#  '77784775': ['68073453'],
#  '75900959': [],
#  '39932592': ['41355028'],
#  '27761735': ['3970310'],
#  '41540672': [],
#  '38980142': [],
#  '23820527': [],
#  '16851438': [],
#  '51593907': [],
#  '58231008': [],
#  '55257031': [],
#  '13936588': [],
#  '68212704': [],
#  '24129823': [],
#  '47866510': ['23834513', '48827406'],
#  '23670828': [],
#  '69221753': [],
#  '52847233': [],
#  '58294008': [],
#  '46934107': [],
#  '49708116': [],
#  '20957475': [],
#  '40353168': [],
#  '31108320': [],
#  '38948715': ['37228044'],
#  '38960613': [],
#  '40225243': ['69410205'],
#  '65115729': [],
#  '23878679': [],
#  '15018469': ['17381885'],
#  '10067253': [],
#  '21315475': [],
#  '52808930': [],
#  '21129437': ['24314496'],
#  '14548300': ['55391329', '61099218'],
#  '59216111': [],
#  '1983199': ['49993131', '16834839', '4288074'],
#  '24216621': [],
#  '23782849': [],
#  '12318084': [],
#  '21858752': [],
#  '14894633': [],
#  '19218387': ['56501993', '5367473', '63030640', '67933305', '77253272'],
#  '72904083': ['71743364', '7498248', '27276773', '70702647'],
#  '59368914': ['58245489'],
#  '48150566': [],
#  '38948950': [],
#  '21138457': [],
#  '41185283': [],
#  '71083907': [],
#  '31080932': [],
#  '20013571': [],
#  '10616097': ['17333038', '9759833', '71470183', '43082486', '16413154'],
#  '41234969': [],
#  '39819644': [],
#  '14787934': ['41262823', '77413114'],
#  '48530851': [],
#  '38863377': [],
#  '14893477': [],
#  '55011716': ['21395569'],
#  '24403971': [],
#  '16911523': [],
#  '45962482': ['61733113', '61744733', '61628183', '61657848'],
#  '29722141': [],
#  '26221140': [],
#  '21871717': [],
#  '24053479': ['50404797'],
#  '15008394': [],
#  '64291781': ['36812151', '40800471', '58174272', '19958304', '71491749'],
#  '20885536': [],
#  '38770686': ['9901505'],
#  '12611772': [],
#  '71193866': ['21042288'],
#  '38067058': [],
#  '21450194': [],
#  '14984613': [],
#  '28567899': ['28546088', '14868113', '32000382', '27265838', '28848143'],
#  '6633898': [],
#  '43202820': [],
#  '48131695': [],
#  '71486071': ['30812052'],
#  '21014411': [],
#  '47972313': [],
#  '44615427': [],
#  '67586613': [],
#  '30214918': [],
#  '9619870': ['4740852'],
#  '61722493': [],
#  '41179412': [],
#  '71351592': ['74036585'],
#  '5311446': [],
#  '42737328': [],
#  '62493828': ['36679873'],
#  '43679269': [],
#  '1697036': [],
#  '21817641': [],
#  '21085558': [],
#  '21746157': [],
#  '56075629': [],
#  '6517968': [],
#  '5215266': [],
#  '41353835': ['38815305', '24403873'],
#  '58378272': [],
#  '38357100': [],
#  '54965102': [],
#  '14941916': [],
#  '61702258': [],
#  '21165365': [],
#  '8181729': [],
#  '23850903': [],
#  '74970707': [],
#  '24660028': ['77788902'],
#  '2900378': [],
#  '43772312': ['65342808', '22668859', '109145'],
#  '14952535': [],
#  '24244122': ['23507092', '23816604', '62248527'],
#  '46078226': [],
#  '49314769': [],
#  '34450948': [],
#  '42607508': [],
#  '69459119': ['66345888'],
#  '38813673': [],
#  '42612470': [],
#  '9436498': [],
#  '72309907': [],
#  '59448821': ['56549689'],
#  '48864586': ['47347300', '63007044'],
#  '14854788': ['21142643'],
#  '62964936': [],
#  '39813393': [],
#  '54990868': [],
#  '244415': [],
#  '55836218': [],
#  '12808064': [],
#  '21930708': [],
#  '71466084': [],
#  '68056601': [],
#  '24268156': [],
#  '47975659': [],
#  '58155116': ['37010405', '71336365'],
#  '67898170': ['64905421'],
#  '39767500': [],
#  '21921246': ['33429162'],
#  '58317172': [],
#  '11483884': [],
#  '41361546': [],
#  '67674302': [],
#  '64308009': ['34322828'],
#  '71345801': [],
#  '58235807': [],
#  '31124302': [],
#  '47988679': ['40701566', '40877891', '9684893'],
#  '4309759': [],
#  '9935496': [],
#  '62422696': ['58415579'],
#  '14662223': [],
#  '24251579': [],
#  '63993077': ['68139647'],
#  '17163798': ['57032801'],
#  '1626843': [],
#  '50840129': [],
#  '24370677': [],
#  '23869219': [],
#  '16995198': [],
#  '67752822': ['71501627', '14830295'],
#  '58381921': [],
#  '74056945': [],
#  '11558794': [],
#  '9756582': [],
#  '49538454': [],
#  '53031778': [],
#  '10566230': [],
#  '14928262': [],
#  '21144733': [],
#  '48010415': ['16873646'],
#  '38818322': [],
#  '41813330': [],
#  '22766353': [],
#  '14680113': [],
#  '57214130': [],
#  '33358927': [],
#  '15355189': ['66089608', '31158362', '40003514', '62686777'],
#  '27479155': [],
#  '71507755': [],
#  '41135041': [],
#  '41634147': ['4020716'],
#  '41367780': [],
#  '63620020': [],
#  '69340233': [],
#  '47027008': [],
#  '67783035': [],
#  '41264117': [],
#  '66306760': ['7317661', '72815933'],
#  '16892814': ['32887382', '71334724', '41161384', '41268197'],
#  '4891523': [],
#  '19409257': ['60246492'],
#  '23826802': ['24423661'],
#  '48142438': ['59472879', '46136200'],
#  '27513086': [],
#  '44479801': [],
#  '21006102': [],
#  '66567975': ['41350659',
#   '60046126',
#   '44783549',
#   '23765505',
#   '17388721',
#   '69950127',
#   '38913188',
#   '22995825',
#   '22528813',
#   '67964144',
#   '71353185',
#   '66903997'],
#  '67597513': [],
#  '50913227': [],
#  '42593289': [],
#  '49378726': [],
#  '49552391': ['73933566', '10970928'],
#  '38947637': [],
#  '21047047': [],
#  '16990289': [],
#  '21703693': ['36644552', '41949030', '48803352'],
#  '42699746': ['7490940'],
#  '71106615': [],
#  '65129652': ['75841301', '53726733', '69761024', '15839643'],
#  '57186994': ['33422831', '16413154', '33100950'],
#  '9419050': [],
#  '11841907': [],
#  '14924019': [],
#  '41216997': [],
#  '6042585': [],
#  '38565232': ['58457256'],
#  '38902165': [],
#  '27344794': [],
#  '41155750': [],
#  '38856202': [],
#  '76920239': [],
#  '49467458': [],
#  '48031991': [],
#  '38765652': [],
#  '34309825': ['37412913', '26281610', '38778313', '13279918', '58368894'],
#  '40058920': [],
#  '27329318': ['60509363', '55928691', '59898081'],
#  '76194575': ['66050644', '63114727'],
#  '12240982': [],
#  '58296157': [],
#  '40495582': [],
#  '1684108': [],
#  '56064016': [],
#  '28716098': [],
#  '68365377': [],
#  '22539189': [],
#  '38502982': [],
#  '16890916': [],
#  '41216735': [],
#  '21111187': [],
#  '6255852': [],
#  '31106144': [],
#  '8860038': ['65474181'],
#  '31303467': ['36211714', '70367579', '66050644', '62944125', '76821305'],
#  '22586759': [],
#  '403249': ['78261732', '70407955', '70272252', '68578838', '62817513'],
#  '29788981': [],
#  '38841336': [],
#  '36229394': ['36110110'],
#  '9408905': [],
#  '17230802': [],
#  '73896770': [],
#  '21976641': [],
#  '62576445': [],
#  '71386196': [],
#  '10405199': ['67747575', '77468618'],
#  '39745033': [],
#  '22707080': ['40726777', '42029636', '62761276', '62704539'],
#  '59139202': [],
#  '66653816': [],
#  '68163705': ['58200339'],
#  '7750955': [],
#  '34779135': [],
#  '58177942': ['23763127'],
#  '38761039': ['11393743'],
#  '66506552': [],
#  '29650090': [],
#  '41228860': [],
#  '68337762': [],
#  '73512758': [],
#  '57199273': [],
#  '71337884': ['41262823', '77413114', '46753188'],
#  '77159177': [],
#  '46151881': ['58278131', '23920215'],
#  '31236143': [],
#  '44037751': [],
#  '21817327': [],
#  '2866430': [],
#  '10285438': ['41350659', '9484855', '33338932'],
#  '3133641': ['48503344', '37286128'],
#  '37618502': [],
#  '47590265': ['16371426'],
#  '10405870': [],
#  '2685650': [],
#  '21899259': [],
#  '67062495': ['48387333'],
#  '13048124': ['42911931'],
#  '32025730': ['32000583', '71462516'],
#  '11420004': [],
#  '64898447': [],
#  '9435429': [],
#  '47975140': [],
#  '71190700': [],
#  '24252592': [],
#  '38815364': [],
#  '47942072': [],
#  '19213528': [],
#  '16898991': ['38513076', '37070454', '51227371', '24418511'],
#  '16872270': [],
#  '48038298': [],
#  '41284004': [],
#  '10657765': [],
#  '61620832': [],
#  '57108868': ['21239648'],
#  '76434225': [],
#  '16063983': ['24224703'],
#  '23801630': ['38998399'],
#  '23956273': [],
#  '58302487': [],
#  '68224577': [],
#  '20900948': [],
#  '68378734': ['49893404'],
#  '18503873': [],
#  '48521932': [],
#  '67920798': ['40023660'],
#  '16902011': [],
#  '24322821': [],
#  '41367206': ['48092773', '77021522'],
#  '61596692': [],
#  '19655374': [],
#  '1592679': [],
#  '48013889': ['74241229'],
#  '10489022': [],
#  '38802798': [],
#  '58300080': [],
#  '27829406': [],
#  '66596977': [],
#  '10512181': [],
#  '71467798': [],
#  '39724992': [],
#  '3174630': ['39644464', '37088758'],
#  '66022980': [],
#  '39053188': [],
#  '1065540': [],
#  '15070655': [],
#  '29767164': [],
#  '41603672': [],
#  '77495515': ['58348094', '20879532'],
#  '23747670': [],
#  '16977103': [],
#  '4905344': [],
#  '24640450': [],
#  '61724165': [],
#  '12711052': [],
#  '65122010': ['42877393'],
#  '14907881': ['37103907', '33024776', '26281756'],
#  '16977864': ['77183501', '38947960', '71541909'],
#  '24149020': ['39961477'],
#  '67687009': [],
#  '47254152': ['45680184', '54901529', '47330749'],
#  '45603731': ['40875610'],
#  '46100859': ['4860362', '69509685'],
#  '58333388': ['20592193', '21969607'],
#  '41589229': [],
#  '35777343': [],
#  '54922972': [],
#  '76291729': [],
#  '24469530': [],
#  '60059810': ['50096270', '5820242', '50165841', '50144491'],
#  '48150520': [],
#  '20964404': [],
#  '32852654': [],
#  '77247659': ['20969912'],
#  '42738182': [],
#  '47916215': [],
#  '38986996': [],
#  '48763170': [],
#  '71330758': ['28465930', '48833177'],
#  '32301829': ['23486417',
#   '39114507',
#   '59263737',
#   '41879969',
#   '69180205',
#   '33872959'],
#  '41606624': [],
#  '6442613': [],
#  '17293231': ['75245976', '71491749'],
#  '62443436': ['62444956', '62432991', '62444068'],
#  '41162374': [],
#  '12279999': [],
#  '14941163': [],
#  '58368548': [],
#  '8094077': [],
#  '29133505': [],
#  '47949055': [],
#  '75200361': ['37436144', '45790615', '48596068'],
#  '11823772': [],
#  '19012573': [],
#  '20896613': [],
#  '12728880': [],
#  '41243358': [],
#  '21021677': ['28315643', '68472686', '58414884', '34699751', '71121468'],
#  '32743077': [],
#  '47876912': ['38855992'],
#  '68318286': ['45275422'],
#  '26178872': [],
#  '40932130': ['31779057'],
#  '33592578': [],
#  '18458224': [],
#  '68300281': ['9684893'],
#  '61636221': ['62390613'],
#  '21729946': [],
#  '14985335': [],
#  '11624431': [],
#  '52992752': [],
#  '59340747': [],
#  '45991789': [],
#  '10484638': ['29156937',
#   '25978100',
#   '49656593',
#   '67269452',
#   '70563508',
#   '72485803',
#   '53735125',
#   '75990576',
#   '18941108',
#   '12798230',
#   '49185395',
#   '61863841',
#   '233990',
#   '48523418',
#   '78414185',
#   '46957704'],
#  '23787450': ['49458076'],
#  '10413191': [],
#  '27697381': [],
#  '23923584': [],
#  '10682759': [],
#  '68525219': [],
#  '56171043': [],
#  '27760898': [],
#  '71354982': [],
#  '67666845': ['38888668', '71402712', '39030678', '38662685', '58337064'],
#  '68789326': ['60509363', '55928691', '59898081'],
#  '68073446': [],
#  '14939857': [],
#  '52809809': ['32901249', '4067290'],
#  '13256216': [],
#  '61647420': [],
#  '66496717': ['7773819', '34820624'],
#  '28562642': [],
#  '13940486': ['9956960', '34800300'],
#  '49646766': [],
#  '2125168': [],
#  '58402110': ['16971200', '41235922', '24415936'],
#  '24345893': [],
#  '21153138': ['41214143'],
#  '4940233': [],
#  '10674143': [],
#  '59190012': [],
#  '41270166': [],
#  '1060625': ['64949607', '23869957', '69557168', '34681748'],
#  '38765975': [],
#  '38997968': [],
#  '49688953': [],
#  '38768789': [],
#  '78321641': [],
#  '29816707': [],
#  '38907740': [],
#  '53011595': ['49428968', '17388721'],
#  '18519138': [],
#  '44300934': ['44189840'],
#  '48056157': [],
#  '48118518': [],
#  '59099025': [],
#  '34889439': [],
#  '24391432': [],
#  '20974106': [],
#  '23929208': ['35858776'],
#  '3801570': [],
#  '11635202': [],
#  '949968': [],
#  '54947955': [],
#  '24403938': [],
#  '1662369': [],
#  '68446306': [],
#  '10641650': [],
#  '66441186': [],
#  '38783283': [],
#  '21867778': [],
#  '41834231': [],
#  '17051301': [],
#  '76185124': [],
#  '77940060': [],
#  '9015959': ['48983763'],
#  '23991970': [],
#  '76764174': [],
#  '44239988': [],
#  '46130311': [],
#  '17489779': ['16982699', '38779914'],
#  '20943170': [],
#  '31169708': [],
#  '71546846': ['41310857'],
#  '48918886': ['34911365'],
#  '39799618': ['18576987', '59120240'],
#  '41257771': [],
#  '14501545': ['26890304', '47957942'],
#  '26548380': [],
#  '47803144': [],
#  '28603821': [],
#  '2891841': [],
#  '58432746': [],
#  '58405526': [],
#  '12588168': [],
#  '71225353': [],
#  '17018465': [],
#  '19103410': [],
#  '71187560': [],
#  '10584798': [],
#  '9847532': [],
#  '64969858': [],
#  '62676533': ['42000481',
#   '62620468',
#   '62765970',
#   '63052748',
#   '62911240',
#   '62906923'],
#  '75384493': [],
#  '15015728': [],
#  '14780466': [],
#  '38439831': [],
#  '52053684': ['3831027', '76808649', '27117351', '31406868', '20165934'],
#  '10926536': [],
#  '48038870': [],
#  '37114047': [],
#  '33545003': ['33037669'],
#  '71239825': [],
#  '58348740': [],
#  '57236058': ['16384229', '61713887'],
#  '56121726': [],
#  '11510981': [],
#  '63415604': [],
#  '33232817': [],
#  '59127869': [],
#  '22323086': [],
#  '24469015': [],
#  '63668129': ['14963328', '10695997'],
#  '9571176': [],
#  '76142585': [],
#  '58957531': ['52590927', '76772733', '26916018'],
#  '11393839': ['58322842'],
#  '21768840': [],
#  '30063736': [],
#  '58262281': [],
#  '67686006': [],
#  '42747722': [],
#  '77492727': ['73845008',
#   '23756252',
#   '2242008',
#   '68582267',
#   '38935773',
#   '70267276'],
#  '61732462': [],
#  '71373338': ['21061696'],
#  '1790866': ['49993131', '16834839'],
#  '38024990': [],
#  '27662181': [],
#  '31256873': [],
#  '25932584': [],
#  '4473083': [],
#  '52666805': [],
#  '66124179': [],
#  '74993565': ['48044940'],
#  '20060559': [],
#  '68052523': ['67944225', '40578486', '58400759', '59182342'],
#  '26450166': [],
#  '14814964': [],
#  '38090267': ['20013571', '71603297'],
#  '58235014': ['58253070',
#   '77773694',
#   '33544524',
#   '55075011',
#   '77804943',
#   '39047603',
#   '71375217',
#   '39008944',
#   '77453412',
#   '10200549',
#   '33192580',
#   '26547200',
#   '15015281',
#   '24388931',
#   '24227296'],
#  '56193640': [],
#  '14234330': [],
#  '21893414': [],
#  '44264669': [],
#  '58374350': [],
#  '14858456': ['41245535'],
#  '16963043': [],
#  '18478948': ['66002386', '18610715'],
#  '71188159': [],
#  '58428493': [],
#  '66030423': [],
#  '15010792': [],
#  '58406027': [],
#  '6471710': [],
#  '41296533': [],
#  '41140825': [],
#  '62200021': [],
#  '39731227': ['39809221'],
#  '58252540': [],
#  '41159140': [],
#  '10786508': [],
#  '58264083': [],
#  '5925494': [],
#  '7515373': ['40640382'],
#  '24084936': [],
#  '25813305': [],
#  '68240360': [],
#  '20813592': [],
#  '48126131': ['23763127'],
#  '36020745': [],
#  '47302741': ['50041006'],
#  '12809532': [],
#  '33705413': [],
#  '23827848': [],
#  '23960224': [],
#  '59168938': [],
#  '58245097': [],
#  '48532130': [],
#  '25024609': ['40875610'],
#  '12752391': ['14804951'],
#  '21629420': [],
#  '16911816': [],
#  '71511221': ['24423661'],
#  '37254616': ['48119811', '64708295'],
#  '14751769': [],
#  '71119844': [],
#  '51546910': [],
#  '41239123': [],
#  '28771194': [],
#  '29727573': [],
#  '66327611': [],
#  '24349688': ['33338932', '21130286'],
#  '21036034': ['64907113', '56459133'],
#  '34096564': [],
#  '20051860': [],
#  '15205410': [],
#  '46956570': ['64032454', '75751275'],
#  '36720643': [],
#  '24112963': [],
#  '14860342': [],
#  '50705645': [],
#  '16880096': [],
#  '41350959': [],
#  '14660009': [],
#  '47986038': [],
#  '14818920': [],
#  '54925425': [],
#  '33753600': ['6053993', '76701461', '47415449'],
#  '31199059': ['57270361', '76334226'],
#  '24330812': [],
#  '22722771': ['46771111'],
#  '24218015': ['23716758'],
#  '75073479': ['41744290'],
#  '21382364': ['67323803', '65070797'],
#  '3880375': ['49748155'],
#  '6314779': ['48721632', '41187392', '41028054', '61517536'],
#  '14457202': ['17381885'],
#  '69478004': [],
#  '10277730': [],
#  '22491846': [],
#  '23828503': [],
#  '32995767': [],
#  '21759846': [],
#  ...}

# %%
number_of_lines = len(open('labels.txt').readlines())
print(number_of_lines)
# Out:
# 18720

# %%
# Dictionary to store to nodes and their labels
label_dict = {}
with open('labels.txt', 'r') as labels:
    labels = [labels.readline().strip() for i in range(0,number_of_lines)]
    for each_line in labels:
        node = each_line.split(' ')[0]
        label = each_line.split(' ')[1]
        label_dict[node] = int(label)

# %%
label_dict
# Out:
# {'12828558': 0,
#  '66779408': 0,
#  '38902949': 0,
#  '33450563': 0,
#  '57470294': 0,
#  '12016981': 0,
#  '59453341': 0,
#  '54791317': 0,
#  '38124547': 0,
#  '44569330': 0,
#  '4289706': 0,
#  '34733903': 0,
#  '67315895': 0,
#  '47899676': 0,
#  '58164272': 0,
#  '76914035': 0,
#  '71555172': 0,
#  '6909690': 0,
#  '47982561': 0,
#  '16864792': 0,
#  '34534740': 0,
#  '27917678': 0,
#  '42441879': 0,
#  '20060161': 0,
#  '54709047': 0,
#  '17112646': 0,
#  '41499729': 0,
#  '39772251': 0,
#  '71431551': 0,
#  '34646799': 0,
#  '72286508': 0,
#  '30054787': 0,
#  '14960319': 0,
#  '20894906': 0,
#  '43560951': 0,
#  '12233872': 0,
#  '58790184': 0,
#  '41345168': 0,
#  '53029990': 0,
#  '17009966': 0,
#  '23095245': 0,
#  '39006078': 0,
#  '22637451': 0,
#  '1418126': 0,
#  '61597421': 0,
#  '62350848': 0,
#  '38208385': 0,
#  '54562160': 0,
#  '47946998': 0,
#  '71174685': 0,
#  '40035502': 0,
#  '14982527': 0,
#  '18559780': 0,
#  '72501271': 0,
#  '10048225': 0,
#  '40080547': 0,
#  '44483771': 0,
#  '6209405': 0,
#  '32265946': 0,
#  '6636178': 0,
#  '38419714': 0,
#  '39765555': 0,
#  '47903875': 0,
#  '38908219': 0,
#  '17144632': 0,
#  '32405512': 0,
#  '58264095': 0,
#  '10592146': 0,
#  '27757876': 0,
#  '12204756': 0,
#  '71425739': 0,
#  '10706160': 0,
#  '47972984': 0,
#  '22492574': 0,
#  '35921598': 0,
#  '52837837': 0,
#  '60341713': 0,
#  '55648908': 0,
#  '14875594': 0,
#  '14875759': 0,
#  '48678541': 0,
#  '6479945': 0,
#  '11546941': 0,
#  '34805002': 0,
#  '21894266': 0,
#  '40202931': 0,
#  '41120230': 0,
#  '61653787': 0,
#  '30370202': 0,
#  '41315669': 0,
#  '76250257': 0,
#  '4122517': 0,
#  '71522410': 0,
#  '46924819': 0,
#  '4925897': 0,
#  '9653400': 0,
#  '47608867': 0,
#  '21909791': 0,
#  '2910962': 0,
#  '47689611': 0,
#  '41333868': 0,
#  '12851109': 0,
#  '48010264': 0,
#  '55708499': 0,
#  '24354444': 0,
#  '2558656': 0,
#  '21092817': 0,
#  '61641625': 0,
#  '24294943': 0,
#  '5665481': 0,
#  '17664420': 0,
#  '9513316': 0,
#  '30173134': 0,
#  '48513318': 0,
#  '49244403': 0,
#  '39795788': 0,
#  '34757287': 0,
#  '27583382': 0,
#  '20157519': 0,
#  '28456696': 0,
#  '20376508': 0,
#  '11695845': 0,
#  '44299936': 0,
#  '14882075': 0,
#  '14788728': 0,
#  '41209535': 0,
#  '41151647': 0,
#  '18445831': 0,
#  '41343198': 0,
#  '28577858': 0,
#  '38798521': 0,
#  '62371398': 0,
#  '75995928': 0,
#  '68358553': 0,
#  '23722119': 0,
#  '37857050': 0,
#  '22529282': 0,
#  '78122623': 0,
#  '10466497': 0,
#  '41164006': 0,
#  '26454883': 0,
#  '4970781': 0,
#  '10390994': 0,
#  '39879054': 0,
#  '12627824': 0,
#  '43166750': 0,
#  '1066092': 0,
#  '41336770': 0,
#  '43039862': 0,
#  '38797216': 0,
#  '15016187': 0,
#  '36780153': 0,
#  '36643490': 0,
#  '28737890': 0,
#  '10307904': 0,
#  '23868126': 0,
#  '39972783': 0,
#  '38937933': 0,
#  '41496134': 0,
#  '38827890': 0,
#  '15247739': 0,
#  '20899547': 0,
#  '53023736': 0,
#  '38764349': 0,
#  '71415626': 0,
#  '54917546': 0,
#  '71439214': 0,
#  '49436076': 0,
#  '54992365': 0,
#  '41304088': 0,
#  '24304624': 0,
#  '39719760': 0,
#  '11415195': 0,
#  '31604510': 0,
#  '25962005': 0,
#  '39777387': 0,
#  '41291987': 0,
#  '48288333': 0,
#  '14772078': 0,
#  '62516668': 0,
#  '21941140': 0,
#  '24772788': 0,
#  '49327894': 0,
#  '23940295': 0,
#  '78051252': 0,
#  '71640753': 0,
#  '12810390': 0,
#  '78304440': 0,
#  '38454176': 0,
#  '61149976': 0,
#  '14771338': 0,
#  '30347996': 0,
#  '24063423': 0,
#  '4752672': 0,
#  '33246577': 0,
#  '41619933': 0,
#  '41646861': 0,
#  '58220404': 0,
#  '10101505': 0,
#  '21125761': 0,
#  '47975082': 0,
#  '41134045': 0,
#  '33217458': 0,
#  '14891394': 0,
#  '14729714': 0,
#  '58295469': 0,
#  '39982987': 0,
#  '16889612': 0,
#  '58388309': 0,
#  '71378273': 0,
#  '27746891': 0,
#  '31534190': 0,
#  '69118961': 0,
#  '68373032': 0,
#  '41411255': 0,
#  '68225895': 0,
#  '20980568': 0,
#  '9496751': 0,
#  '26565898': 0,
#  '58557307': 0,
#  '16864312': 0,
#  '6037711': 0,
#  '17171119': 0,
#  '173889': 0,
#  '10439370': 0,
#  '5617161': 0,
#  '29148119': 0,
#  '58294066': 0,
#  '46057239': 0,
#  '24069155': 0,
#  '61572401': 0,
#  '56071758': 0,
#  '12578252': 0,
#  '12165989': 0,
#  '68299079': 0,
#  '66140144': 0,
#  '28893614': 0,
#  '34635686': 0,
#  '71251765': 0,
#  '50752517': 0,
#  '21972954': 0,
#  '1672961': 0,
#  '59059111': 0,
#  '38924375': 0,
#  '49317707': 0,
#  '71137680': 0,
#  '16108347': 0,
#  '28616654': 0,
#  '24430361': 0,
#  '69353883': 0,
#  '39048535': 0,
#  '39003766': 0,
#  '61537477': 0,
#  '77120777': 0,
#  '24390096': 0,
#  '30113491': 0,
#  '59483832': 0,
#  '72019098': 0,
#  '68042128': 0,
#  '68901967': 0,
#  '58392932': 0,
#  '18755216': 0,
#  '52940064': 0,
#  '27382572': 0,
#  '66393674': 0,
#  '34485235': 0,
#  '15014594': 0,
#  '4929958': 0,
#  '47958938': 0,
#  '71282186': 0,
#  '23979720': 0,
#  '40166660': 0,
#  '47073715': 0,
#  '1759342': 0,
#  '61739905': 0,
#  '62552337': 0,
#  '39988416': 0,
#  '41155604': 0,
#  '31161813': 0,
#  '38856210': 0,
#  '11718927': 0,
#  '18538685': 0,
#  '33650615': 0,
#  '24305544': 0,
#  '66104530': 0,
#  '77143630': 0,
#  '7755678': 0,
#  '23431945': 0,
#  '48084177': 0,
#  '68172232': 0,
#  '24929027': 0,
#  '47973358': 0,
#  '68157888': 0,
#  '32043684': 0,
#  '38950127': 0,
#  '21696827': 0,
#  '67857807': 0,
#  '21120101': 0,
#  '6628255': 0,
#  '38545472': 0,
#  '7607033': 0,
#  '34538987': 0,
#  '69237364': 0,
#  '16846973': 0,
#  '58265390': 0,
#  '43211472': 0,
#  '67416370': 0,
#  '41523113': 0,
#  '10715981': 0,
#  '6692256': 0,
#  '41628667': 0,
#  '69506486': 0,
#  '68437247': 0,
#  '62444762': 0,
#  '41261282': 0,
#  '11783496': 0,
#  '24381181': 0,
#  '9835099': 0,
#  '12808129': 0,
#  '31956150': 0,
#  '11686379': 0,
#  '8163785': 0,
#  '47882750': 0,
#  '23956993': 0,
#  '38496230': 0,
#  '38832438': 0,
#  '76569872': 0,
#  '43193462': 0,
#  '41273776': 0,
#  '40578486': 0,
#  '48023609': 0,
#  '66163292': 0,
#  '46973934': 0,
#  '1927922': 0,
#  '31142879': 0,
#  '37833861': 0,
#  '20931265': 0,
#  '41535039': 0,
#  '10648670': 0,
#  '39957493': 0,
#  '14999062': 0,
#  '35926213': 0,
#  '48021246': 0,
#  '24420113': 0,
#  '10455461': 0,
#  '24066961': 0,
#  '41088230': 0,
#  '71997781': 0,
#  '74134188': 0,
#  '24337290': 0,
#  '33835248': 0,
#  '14965504': 0,
#  '14402931': 0,
#  '41490200': 0,
#  '6207388': 0,
#  '10633811': 0,
#  '14783772': 0,
#  '39985569': 0,
#  '41725313': 0,
#  '24196018': 0,
#  '14762137': 0,
#  '34732837': 0,
#  '2674219': 0,
#  '15008773': 0,
#  '69456069': 0,
#  '44326112': 0,
#  '33883329': 0,
#  '6464062': 0,
#  '77028800': 0,
#  '64032454': 0,
#  '40337167': 0,
#  '29615978': 0,
#  '33071446': 0,
#  '77784775': 0,
#  '75900959': 0,
#  '39932592': 0,
#  '27761735': 0,
#  '41540672': 0,
#  '38980142': 0,
#  '23820527': 0,
#  '16851438': 0,
#  '51593907': 0,
#  '58231008': 0,
#  '55257031': 0,
#  '13936588': 0,
#  '68212704': 0,
#  '24129823': 0,
#  '47866510': 0,
#  '23670828': 0,
#  '69221753': 0,
#  '52847233': 0,
#  '58294008': 0,
#  '46934107': 0,
#  '49708116': 0,
#  '20957475': 0,
#  '40353168': 0,
#  '31108320': 0,
#  '38948715': 0,
#  '38960613': 0,
#  '40225243': 0,
#  '65115729': 0,
#  '23878679': 0,
#  '15018469': 0,
#  '10067253': 0,
#  '21315475': 0,
#  '52808930': 0,
#  '21129437': 0,
#  '14548300': 0,
#  '59216111': 0,
#  '1983199': 0,
#  '24216621': 0,
#  '23782849': 0,
#  '12318084': 0,
#  '21858752': 0,
#  '14894633': 0,
#  '19218387': 0,
#  '72904083': 0,
#  '59368914': 0,
#  '48150566': 0,
#  '38948950': 0,
#  '21138457': 0,
#  '41185283': 0,
#  '71083907': 0,
#  '31080932': 0,
#  '20013571': 0,
#  '10616097': 0,
#  '41234969': 0,
#  '39819644': 0,
#  '14787934': 0,
#  '48530851': 0,
#  '38863377': 0,
#  '14893477': 0,
#  '55011716': 0,
#  '24403971': 0,
#  '16911523': 0,
#  '45962482': 0,
#  '29722141': 0,
#  '26221140': 0,
#  '21871717': 0,
#  '24053479': 0,
#  '15008394': 0,
#  '64291781': 0,
#  '20885536': 0,
#  '38770686': 0,
#  '12611772': 0,
#  '71193866': 0,
#  '38067058': 0,
#  '21450194': 0,
#  '14984613': 0,
#  '28567899': 0,
#  '6633898': 0,
#  '43202820': 0,
#  '48131695': 0,
#  '71486071': 0,
#  '21014411': 0,
#  '47972313': 0,
#  '44615427': 0,
#  '67586613': 0,
#  '30214918': 0,
#  '9619870': 0,
#  '61722493': 0,
#  '41179412': 0,
#  '71351592': 0,
#  '5311446': 0,
#  '42737328': 0,
#  '62493828': 0,
#  '43679269': 0,
#  '1697036': 0,
#  '21817641': 0,
#  '21085558': 0,
#  '21746157': 0,
#  '56075629': 0,
#  '6517968': 0,
#  '5215266': 0,
#  '41353835': 0,
#  '58378272': 0,
#  '38357100': 0,
#  '54965102': 0,
#  '14941916': 0,
#  '61702258': 0,
#  '21165365': 0,
#  '8181729': 0,
#  '23850903': 0,
#  '74970707': 0,
#  '24660028': 0,
#  '2900378': 0,
#  '43772312': 0,
#  '14952535': 0,
#  '24244122': 0,
#  '46078226': 0,
#  '49314769': 0,
#  '34450948': 0,
#  '42607508': 0,
#  '69459119': 0,
#  '38813673': 0,
#  '42612470': 0,
#  '9436498': 0,
#  '72309907': 0,
#  '59448821': 0,
#  '48864586': 0,
#  '14854788': 0,
#  '62964936': 0,
#  '39813393': 0,
#  '54990868': 0,
#  '244415': 0,
#  '55836218': 0,
#  '12808064': 0,
#  '21930708': 0,
#  '71466084': 0,
#  '68056601': 0,
#  '24268156': 0,
#  '47975659': 0,
#  '58155116': 0,
#  '67898170': 0,
#  '39767500': 0,
#  '21921246': 0,
#  '58317172': 0,
#  '11483884': 0,
#  '41361546': 0,
#  '67674302': 0,
#  '64308009': 0,
#  '71345801': 0,
#  '58235807': 0,
#  '31124302': 0,
#  '47988679': 0,
#  '4309759': 0,
#  '9935496': 0,
#  '62422696': 0,
#  '14662223': 0,
#  '24251579': 0,
#  '63993077': 0,
#  '17163798': 0,
#  '1626843': 0,
#  '50840129': 0,
#  '24370677': 0,
#  '23869219': 0,
#  '16995198': 0,
#  '67752822': 0,
#  '58381921': 0,
#  '74056945': 0,
#  '11558794': 0,
#  '9756582': 0,
#  '49538454': 0,
#  '53031778': 0,
#  '10566230': 0,
#  '14928262': 0,
#  '21144733': 0,
#  '48010415': 0,
#  '38818322': 0,
#  '41813330': 0,
#  '22766353': 0,
#  '14680113': 0,
#  '57214130': 0,
#  '33358927': 0,
#  '15355189': 0,
#  '27479155': 0,
#  '71507755': 0,
#  '41135041': 0,
#  '41634147': 0,
#  '41367780': 0,
#  '63620020': 0,
#  '69340233': 0,
#  '47027008': 0,
#  '67783035': 0,
#  '41264117': 0,
#  '66306760': 0,
#  '16892814': 0,
#  '4891523': 0,
#  '19409257': 0,
#  '23826802': 0,
#  '48142438': 0,
#  '27513086': 0,
#  '44479801': 0,
#  '21006102': 0,
#  '66567975': 0,
#  '67597513': 0,
#  '50913227': 0,
#  '42593289': 0,
#  '49378726': 0,
#  '49552391': 0,
#  '38947637': 0,
#  '21047047': 0,
#  '16990289': 0,
#  '21703693': 0,
#  '42699746': 0,
#  '71106615': 0,
#  '65129652': 0,
#  '57186994': 0,
#  '9419050': 0,
#  '11841907': 0,
#  '14924019': 0,
#  '41216997': 0,
#  '6042585': 0,
#  '38565232': 0,
#  '38902165': 0,
#  '27344794': 0,
#  '41155750': 0,
#  '38856202': 0,
#  '76920239': 0,
#  '49467458': 0,
#  '48031991': 0,
#  '38765652': 0,
#  '34309825': 0,
#  '40058920': 0,
#  '27329318': 0,
#  '76194575': 0,
#  '12240982': 0,
#  '58296157': 0,
#  '40495582': 0,
#  '1684108': 0,
#  '56064016': 0,
#  '28716098': 0,
#  '68365377': 0,
#  '22539189': 0,
#  '38502982': 0,
#  '16890916': 0,
#  '41216735': 0,
#  '21111187': 0,
#  '6255852': 0,
#  '31106144': 0,
#  '8860038': 0,
#  '31303467': 0,
#  '22586759': 0,
#  '403249': 0,
#  '29788981': 0,
#  '38841336': 0,
#  '36229394': 0,
#  '9408905': 0,
#  '17230802': 0,
#  '73896770': 0,
#  '21976641': 0,
#  '62576445': 0,
#  '71386196': 0,
#  '10405199': 0,
#  '39745033': 0,
#  '22707080': 0,
#  '59139202': 0,
#  '66653816': 0,
#  '68163705': 0,
#  '7750955': 0,
#  '34779135': 0,
#  '58177942': 0,
#  '38761039': 0,
#  '66506552': 0,
#  '29650090': 0,
#  '41228860': 0,
#  '68337762': 0,
#  '73512758': 0,
#  '57199273': 0,
#  '71337884': 0,
#  '77159177': 0,
#  '46151881': 0,
#  '31236143': 0,
#  '44037751': 0,
#  '21817327': 0,
#  '2866430': 0,
#  '10285438': 0,
#  '3133641': 0,
#  '37618502': 0,
#  '47590265': 0,
#  '10405870': 0,
#  '2685650': 0,
#  '21899259': 0,
#  '67062495': 0,
#  '13048124': 0,
#  '32025730': 0,
#  '11420004': 0,
#  '64898447': 0,
#  '9435429': 0,
#  '47975140': 0,
#  '71190700': 0,
#  '24252592': 0,
#  '38815364': 0,
#  '47942072': 0,
#  '19213528': 0,
#  '16898991': 0,
#  '16872270': 0,
#  '48038298': 0,
#  '41284004': 0,
#  '10657765': 0,
#  '61620832': 0,
#  '57108868': 0,
#  '76434225': 0,
#  '16063983': 0,
#  '23801630': 0,
#  '23956273': 0,
#  '58302487': 0,
#  '68224577': 0,
#  '20900948': 0,
#  '68378734': 0,
#  '18503873': 0,
#  '48521932': 0,
#  '67920798': 0,
#  '16902011': 0,
#  '24322821': 0,
#  '41367206': 0,
#  '61596692': 0,
#  '19655374': 0,
#  '1592679': 0,
#  '48013889': 0,
#  '10489022': 0,
#  '38802798': 0,
#  '58300080': 0,
#  '27829406': 0,
#  '66596977': 0,
#  '10512181': 0,
#  '71467798': 0,
#  '39724992': 0,
#  '3174630': 0,
#  '66022980': 0,
#  '39053188': 0,
#  '1065540': 0,
#  '15070655': 0,
#  '29767164': 0,
#  '41603672': 0,
#  '77495515': 0,
#  '23747670': 0,
#  '16977103': 0,
#  '4905344': 0,
#  '24640450': 0,
#  '61724165': 0,
#  '12711052': 0,
#  '65122010': 0,
#  '14907881': 0,
#  '16977864': 0,
#  '24149020': 0,
#  '67687009': 0,
#  '47254152': 0,
#  '45603731': 0,
#  '46100859': 0,
#  '58333388': 0,
#  '41589229': 0,
#  '35777343': 0,
#  '54922972': 0,
#  '76291729': 0,
#  '24469530': 0,
#  '60059810': 0,
#  '48150520': 0,
#  '20964404': 0,
#  '32852654': 0,
#  '77247659': 0,
#  '42738182': 0,
#  '47916215': 0,
#  '38986996': 0,
#  '48763170': 0,
#  '71330758': 0,
#  '32301829': 0,
#  '41606624': 0,
#  '6442613': 0,
#  '17293231': 0,
#  '62443436': 0,
#  '41162374': 0,
#  '12279999': 0,
#  '14941163': 0,
#  '58368548': 0,
#  '8094077': 0,
#  '29133505': 0,
#  '47949055': 0,
#  '75200361': 0,
#  '11823772': 0,
#  '19012573': 0,
#  '20896613': 0,
#  '12728880': 0,
#  '41243358': 0,
#  '21021677': 0,
#  '32743077': 0,
#  '47876912': 0,
#  '68318286': 0,
#  '26178872': 0,
#  '40932130': 0,
#  '33592578': 0,
#  '18458224': 0,
#  '68300281': 0,
#  '61636221': 0,
#  '21729946': 0,
#  '14985335': 0,
#  '11624431': 0,
#  '52992752': 0,
#  '59340747': 0,
#  '45991789': 0,
#  '10484638': 0,
#  '23787450': 0,
#  '10413191': 0,
#  '27697381': 0,
#  '23923584': 0,
#  '10682759': 0,
#  '68525219': 0,
#  '56171043': 0,
#  '27760898': 0,
#  '71354982': 0,
#  '67666845': 0,
#  '68789326': 0,
#  '68073446': 0,
#  '14939857': 0,
#  '52809809': 0,
#  '13256216': 0,
#  '61647420': 0,
#  '66496717': 0,
#  '28562642': 0,
#  '13940486': 0,
#  '49646766': 0,
#  '2125168': 0,
#  '58402110': 0,
#  '24345893': 0,
#  '21153138': 0,
#  '4940233': 0,
#  '10674143': 0,
#  '59190012': 0,
#  '41270166': 0,
#  '1060625': 0,
#  '38765975': 0,
#  '38997968': 0,
#  '49688953': 0,
#  '38768789': 0,
#  '78321641': 0,
#  '29816707': 0,
#  '38907740': 0,
#  '53011595': 0,
#  '18519138': 0,
#  '44300934': 0,
#  '48056157': 0,
#  '48118518': 0,
#  '59099025': 0,
#  '34889439': 0,
#  '24391432': 0,
#  '20974106': 0,
#  '23929208': 0,
#  '3801570': 0,
#  '11635202': 0,
#  '949968': 0,
#  '54947955': 0,
#  '24403938': 0,
#  '1662369': 0,
#  '68446306': 0,
#  '10641650': 0,
#  '66441186': 0,
#  '38783283': 0,
#  '21867778': 0,
#  '41834231': 0,
#  '17051301': 0,
#  '76185124': 0,
#  '77940060': 0,
#  '9015959': 0,
#  '23991970': 0,
#  '76764174': 0,
#  '44239988': 0,
#  '46130311': 0,
#  '17489779': 0,
#  '20943170': 0,
#  '31169708': 0,
#  '71546846': 0,
#  '48918886': 0,
#  '39799618': 0,
#  '41257771': 0,
#  '14501545': 0,
#  '26548380': 0,
#  '47803144': 0,
#  '28603821': 0,
#  '2891841': 0,
#  '58432746': 0,
#  '58405526': 0,
#  '12588168': 0,
#  '71225353': 0,
#  '17018465': 0,
#  '19103410': 0,
#  '71187560': 0,
#  '10584798': 0,
#  '9847532': 0,
#  '64969858': 0,
#  '62676533': 0,
#  '75384493': 0,
#  '15015728': 0,
#  '14780466': 0,
#  '38439831': 0,
#  '52053684': 0,
#  '10926536': 0,
#  '48038870': 0,
#  '37114047': 0,
#  '33545003': 0,
#  '71239825': 0,
#  '58348740': 0,
#  '57236058': 0,
#  '56121726': 0,
#  '11510981': 0,
#  '63415604': 0,
#  '33232817': 0,
#  '59127869': 0,
#  '22323086': 0,
#  '24469015': 0,
#  '63668129': 0,
#  '9571176': 0,
#  '76142585': 0,
#  '58957531': 0,
#  '11393839': 0,
#  '21768840': 0,
#  '30063736': 0,
#  '58262281': 0,
#  '67686006': 0,
#  '42747722': 0,
#  '77492727': 0,
#  '61732462': 0,
#  '71373338': 0,
#  '1790866': 0,
#  '38024990': 0,
#  '27662181': 0,
#  '31256873': 0,
#  '25932584': 0,
#  '4473083': 0,
#  '52666805': 0,
#  '66124179': 0,
#  '74993565': 0,
#  '20060559': 0,
#  '68052523': 0,
#  '26450166': 0,
#  '14814964': 0,
#  '38090267': 0,
#  '58235014': 0,
#  '56193640': 0,
#  '14234330': 0,
#  '21893414': 0,
#  '44264669': 0,
#  '58374350': 0,
#  '14858456': 0,
#  '16963043': 0,
#  '18478948': 0,
#  '71188159': 0,
#  '58428493': 0,
#  '66030423': 0,
#  '15010792': 0,
#  '58406027': 0,
#  '6471710': 0,
#  '41296533': 0,
#  '41140825': 0,
#  '62200021': 0,
#  '39731227': 0,
#  '58252540': 0,
#  '41159140': 0,
#  '10786508': 0,
#  '58264083': 0,
#  '5925494': 0,
#  '7515373': 0,
#  '24084936': 0,
#  '25813305': 0,
#  '68240360': 0,
#  '20813592': 0,
#  '48126131': 0,
#  '36020745': 0,
#  '47302741': 0,
#  '12809532': 0,
#  '33705413': 0,
#  '23827848': 0,
#  '23960224': 0,
#  '59168938': 0,
#  '58245097': 0,
#  '48532130': 0,
#  '25024609': 0,
#  '12752391': 0,
#  '21629420': 0,
#  '16911816': 0,
#  '71511221': 0,
#  '37254616': 0,
#  '14751769': 0,
#  '71119844': 0,
#  '51546910': 0,
#  '41239123': 0,
#  '28771194': 0,
#  '29727573': 0,
#  '66327611': 0,
#  '24349688': 0,
#  '21036034': 0,
#  '34096564': 0,
#  '20051860': 0,
#  '15205410': 0,
#  '46956570': 0,
#  '36720643': 0,
#  '24112963': 0,
#  '14860342': 0,
#  '50705645': 0,
#  '16880096': 0,
#  '41350959': 0,
#  '14660009': 0,
#  '47986038': 0,
#  '14818920': 0,
#  '54925425': 0,
#  '33753600': 0,
#  '31199059': 0,
#  '24330812': 0,
#  '22722771': 0,
#  '24218015': 0,
#  '75073479': 0,
#  '21382364': 0,
#  '3880375': 0,
#  '6314779': 0,
#  '14457202': 0,
#  '69478004': 0,
#  '10277730': 0,
#  '22491846': 0,
#  '23828503': 0,
#  '32995767': 0,
#  '21759846': 0,
#  ...}

# %%
# initialising undirected graph
g = nx.Graph()
ug = g.to_undirected()

# %%
# Creating a undirected graph with the nodes and edges
for node,edge in edges_dict.items():
    ug.add_node(node) 
    for edges in edge:
        ug.add_edge(node,edges)

# %%
# No of nodes and edges in undirected graph
print("No of nodes: ",len(ug.nodes()))
print("No of edges: ",len(ug.edges()))
# Out:
# No of nodes:  36928
# No of edges:  54183

# %%
#Finding the no label nodes
no_label_nodes = []
for node in ug.nodes():
    if node in label_dict.keys():
        continue
    else:
        no_label_nodes.append(node)

# %%
#Removing no label nodes from the created undirected graph
for node in no_label_nodes:
    ug.remove_node(node)

# %%
# No of nodes and edges in undirected graph after removing no label nodes
print("No of nodes: ",len(ug.nodes()))
print("No of edges: ",len(ug.edges()))
# Out:
# No of nodes:  18720
# No of edges:  9618

# %%
#Finding the true labels for the undirected graph
true_labels = []
for node in ug.nodes():
    if node in label_dict.keys():
        true_labels.append(label_dict[node])

# %%
# unique values in true_labels
np.unique(true_labels)
# Out:
# array([0, 1, 2, 3, 4])

# %%
# length of the true labels
len(true_labels)
# Out:
# 18720

# %% [markdown]
# ## Spectral Clustering for K clusters

# %% [markdown]
# #### Preprocessing and getting the laplacian matrix

# %%
#Laplacian matrix for 'ug' undirected graph
L = nx.laplacian_matrix(ug).astype(float)

# %% [markdown]
# #### Decomposition - Computing eigenvalues and eigenvectors of the matrix

# %%
w,v = sp.sparse.linalg.eigsh(L, k = 3,which='SM')

# %%
print(w)
print(v)
# Out:
# [-3.86204863e-13  3.14602632e-14  6.98483170e-04]
# [[-2.86655492e-03  5.98309986e-03 -2.05553861e-15]
#  [ 5.76174166e-06  1.30951803e-05 -6.31285603e-18]
#  [ 7.09819813e-05 -1.39602761e-02  8.31134513e-15]
#  ...
#  [-1.02010836e-03  5.36606338e-03 -2.84139963e-15]
#  [-1.66227638e-02  9.90473133e-03 -7.27869329e-15]
#  [ 1.43742456e-03 -6.06371550e-03  1.47750498e-15]]

# %%
print(w.shape, v.shape)
X = v*w
# Out:
# (3,) (18720, 3)

# %%
X.shape
# Out:
# (18720, 3)

# %%
#K-means clusrtering
from sklearn.cluster import KMeans

kmeans = KMeans(init='k-means++', n_clusters=5, n_init=10)
kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
error = kmeans.inertia_

# %%
np.unique(labels) # unique values in the labels which generated by k-means clustering
# Out:
# array([0, 1, 2, 3, 4], dtype=int32)

# %%
np.unique(true_labels) #unique values in the true labels
# Out:
# array([0, 1, 2, 3, 4])

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score
normalized_mutual_info_score(true_labels,labels)
# Out:
# 0.18031566832673657

# %% [markdown]
# Received pretty low normalized mutual info score **0.18031566832673657** with the K-means clustering.

# %%
# MiniBatchKMeans clustering 
from sklearn.cluster import MiniBatchKMeans

kmeans1 = MiniBatchKMeans(init='k-means++', n_clusters=5,n_init=20, max_no_improvement=10, verbose=0)
kmeans1.fit_predict(X)
centroids = kmeans1.cluster_centers_
labels = kmeans1.labels_
error = kmeans1.inertia_

from sklearn.metrics.cluster import normalized_mutual_info_score
normalized_mutual_info_score(true_labels,labels)
# Out:
# 0.17861568609642567

# %% [markdown]
# Received normalized mutual info score which is lower than the k-means clustering **0.17861568609642567** with MiniBatchKMeans clustering.

# %%
# KMedoids clustering with the nodes

# !pip install scikit-learn-extra
from sklearn_extra.cluster import KMedoids

kmedoids = KMedoids(n_clusters=5,init = "build")
kmedoids.fit_predict(X)
centroids = kmedoids.cluster_centers_
labels = kmedoids.labels_
error = kmedoids.inertia_

from sklearn.metrics.cluster import normalized_mutual_info_score
normalized_mutual_info_score(true_labels,labels)
# Out:
# 0.1803156683267365

# %% [markdown]
# ## Node Embedding Approach

# %%
# !pip install Node2Vec
from node2vec import Node2Vec
# Out:
# /Users/chaitanyamuvva/opt/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# pre-compute the probabilities and generate walks
node2vec = Node2Vec(ug, dimensions=64, walk_length=30, num_walks=200, workers=4)
# embedding the nodes
model = node2vec.fit(window=10,min_count=1,batch_words=4)
# Out:
# Computing transition probabilities:   0%|          | 0/18720 [00:00<?, ?it/s]

# %%
model.wv.get_vector('12828558') # generated vector of the node '12828558'
# Out:
# array([-0.00223427, -0.01299316, -0.00167405,  0.00092839, -0.00389336,
#        -0.00281923, -0.00663311,  0.00712194, -0.01522242, -0.0039479 ,
#         0.00550015,  0.01333038,  0.01327867,  0.01115854, -0.00229118,
#        -0.00143999, -0.00222812,  0.00936443,  0.00690489, -0.0142027 ,
#        -0.00204141, -0.01434673,  0.01322021,  0.00472553,  0.01137705,
#        -0.00972108, -0.01245281,  0.01094597,  0.01463688, -0.01470541,
#         0.00850832, -0.00659143,  0.00138195, -0.00497295, -0.0029316 ,
#         0.00319988,  0.00607507, -0.00885461, -0.0123937 ,  0.01405009,
#         0.00692496, -0.0115492 ,  0.00870955, -0.00422031, -0.01385356,
#        -0.01535177, -0.00841296,  0.01353357,  0.00213606,  0.00220297,
#        -0.01309112, -0.01181988, -0.00499053, -0.01079274,  0.0030236 ,
#         0.00432758,  0.00878733, -0.00856931,  0.01466512,  0.00176107,
#        -0.00371283,  0.00045177, -0.00917739,  0.00381868], dtype=float32)

# %%
model.wv.most_similar('12828558') # generated '12828558' similar nodes
# Out:
# [('54990868', 0.5018340945243835),
#  ('70141902', 0.46260231733322144),
#  ('11486624', 0.43991661071777344),
#  ('21938655', 0.4212236702442169),
#  ('50434168', 0.42107093334198),
#  ('50245222', 0.40704208612442017),
#  ('71171254', 0.4033096432685852),
#  ('19704826', 0.4002232551574707),
#  ('21003672', 0.39824992418289185),
#  ('41223979', 0.39363744854927063)]

# %%
# Appending all the node vectors to the node_vector list
node_vectors = []
for node in ug.nodes():
    node_vectors.append(model.wv.get_vector(node))

# %%
len(node_vectors) #length of the node_vectors
# Out:
# 18720

# %%
# K-means clustering with the node embeddings of each node
kmeans = KMeans(init='k-means++', n_clusters=5, n_init=10)
kmeans.fit_predict(node_vectors)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
error = kmeans.inertia_

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score
normalized_mutual_info_score(true_labels,labels)
# Out:
# 0.3088381573803444

# %% [markdown]
# There is an improvement in the normalized mutual info score when clustering using the node embeddings. The normalized mutual info score received from the above method is **0.3088381573803444**.

# %%
# MiniBatchKMeans clustering with the node embeddings of each node
from sklearn.cluster import MiniBatchKMeans

kmeans1 = MiniBatchKMeans(init='k-means++', n_clusters=5,n_init=20, max_no_improvement=10, verbose=0)
kmeans1.fit_predict(node_vectors)
centroids = kmeans1.cluster_centers_
labels = kmeans1.labels_
error = kmeans1.inertia_

from sklearn.metrics.cluster import normalized_mutual_info_score
normalized_mutual_info_score(true_labels,labels)
# Out:
# 0.25899971266746497

# %% [markdown]
# K-means clustering is performing better compared to the MiniBatchKMeans when comparing with the normalized mutual info score. The normalized mutual info score for MiniBatchKmeans is **0.25899971266746497**

# %%
# KMedoids clustering with the node embeddings of each node

# !pip install scikit-learn-extra
from sklearn_extra.cluster import KMedoids

kmedoids = KMedoids(n_clusters=5,init = "build")
kmedoids.fit_predict(node_vectors)
centroids = kmedoids.cluster_centers_
labels = kmedoids.labels_
error = kmedoids.inertia_

from sklearn.metrics.cluster import normalized_mutual_info_score
normalized_mutual_info_score(true_labels,labels)
# Out:
# 0.29474648392478503

# %% [markdown]
# The normalized mutual info score for KMedoids is **0.29474648392478503**. The normalized mutual info score for the KMedoids is almost similar to the K-means clustering.
